# %%
import pandas as pd

import pydotplus #pip install pydotplus
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
#https://www.kaggle.com/datasets
df = pd.read_csv('climate_change_indicators.csv')

df.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# 2  Food and Agriculture Organization of the Unite...     ECCS
# 3  Food and Agriculture Organization of the Unite...     ECCS
# 4  Food and Agriculture Organization of the Unite...     ECCS
#
#                      CTS_Name  \
# 0  Surface Temperature Change
# 1  Surface Temperature Change
# 2  Surface Temperature Change
# 3  Surface Temperature Change
# 4  Surface Temperature Change
#
#                                  CTS_Full_Descriptor  ...  F2013  F2014  \
# 0  Environment, Climate Change, Climate Indicator...  ...  1.281  0.456
# 1  Environment, Climate Change, Climate Indicator...  ...  1.333  1.198
# 2  Environment, Climate Change, Climate Indicator...  ...  1.192  1.690
# 3  Environment, Climate Change, Climate Indicator...  ...  1.257  1.170
# 4  Environment, Climate Change, Climate Indicator...  ...  0.831  1.946
#
#    F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 0  1.093  1.555  1.540  1.544  0.910  0.498  1.327  2.012
# 1  1.569  1.464  1.121  2.028  1.675  1.498  1.536  1.518
# 2  1.121  1.757  1.512  1.210  1.115  1.926  2.330  1.688
# 3  1.009  1.539  1.435  1.189  1.539  1.430  1.268  1.256
# 4  1.690  1.990  1.925  1.919  1.964  2.562  1.533  3.243
#
# [5 rows x 72 columns]

# %%
df = df.drop(columns=['ObjectId', 'Country', 'ISO2', 'ISO3', 
         'Indicator', 'Unit', 'CTS_Code', 'CTS_Name',
        'CTS_Full_Descriptor'])#cortando colunas
#df.head()
X = df.drop(columns=['Source'])
Y = df['Source']#class é o dado que calcula acerto e erro

# Separando os dados em treinamento(75%) e teste(25%)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)
print(X_train)
print(Y_train)
# Out:
#      F1961  F1962  F1963  F1964  F1965  F1966  F1967  F1968  F1969  F1970  \
# 166 -0.019 -0.291  0.001 -0.113 -0.301  0.002 -0.261 -0.095  0.166  0.192
# 13     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 74   0.990 -0.750 -1.084 -0.328 -0.814  0.407  0.868  0.204 -0.111 -0.832
# 106 -0.225  0.800  0.485 -0.781  0.051  0.776 -0.621 -0.253  0.375  0.514
# 180  0.097  0.093 -0.075  0.130 -0.478 -0.139 -0.138 -0.142  0.244  0.149
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 88   1.176 -0.419 -0.463 -0.877 -0.883  0.755  0.594  0.383 -0.276 -0.508
# 5    0.041 -0.152 -0.190 -0.229 -0.196  0.175 -0.081 -0.193  0.188  0.248
# 86   0.735  0.079 -0.137  0.199 -0.415  0.264  0.169  0.036  0.002 -0.130
# 62     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 125 -0.047  0.140  0.103  0.057 -0.530  0.112 -0.248 -0.481  0.612  0.701
#
#      ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  F2020  F2021  F2022
# 166  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13   ...  1.574  1.252  1.672  1.530  1.308  2.240  1.997  2.015  2.061  2.080
# 74   ...  0.583  2.519  1.674  1.988  1.653  2.393  2.332  2.516  1.325  2.596
# 106  ...  1.349  1.451  2.104  1.695  1.962  2.358  1.895  1.975  2.676  2.275
# 180  ...  0.789  0.766  0.674    NaN    NaN    NaN    NaN  1.185  0.955  1.038
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 88   ...  1.159  2.229  2.067  1.890  1.336  2.524  2.353  1.990  1.430  2.142
# 5    ...  1.044  0.828  1.331  1.609  0.870  1.395  1.752  1.162  1.553  1.212
# 86   ...  0.866  1.370  1.518  1.598  1.318  1.837  1.591  1.734  1.546  2.028
# 62   ...  1.183  2.447  2.377  1.936  1.502  2.413  2.218  3.625  2.167  1.961
# 125  ...  1.588  1.480  1.563  1.825  2.141  1.086  1.435  1.919  1.855  1.711
#
# [168 rows x 62 columns]
# 166    Temperature change with respect to a baseline ...
# 13     Temperature change with respect to a baseline ...
# 74     Temperature change with respect to a baseline ...
# 106    Temperature change with respect to a baseline ...
# 180    Temperature change with respect to a baseline ...
#                              ...
# 88     Temperature change with respect to a baseline ...
# 5      Temperature change with respect to a baseline ...
# 86     Temperature change with respect to a baseline ...
# 62     Temperature change with respect to a baseline ...
# 125    Temperature change with respect to a baseline ...
# Name: Indicator, Length: 168, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=0)

dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn import tree


tree.plot_tree(dt)
tree.plot_tree(dt, feature_names = X.columns);

# %%
from sklearn.datasets import load_iris
from sklearn import tree


clf = tree.DecisionTreeClassifier(random_state=0)
iris = load_iris()
clf = clf.fit(iris.data, iris.target)
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
#from sklearn.metrics import accuracy_score

#Yhat = dt.predict(X_test)

#print("Acurácia dos dados de teste  : ", accuracy_score(Y_test,Yhat))

# %%
#from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#import matplotlib.pyplot as plt

# Displaying the confusion matrix

#cm = confusion_matrix(Y_test, Yhat, labels=dt.classes_)

#disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt.classes_)

#disp.plot()

#plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 200, max_features = 3)

rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_features=3, n_estimators=200)

# %%
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

result = permutation_importance(rf, X_test, Y_test,n_repeats=30, random_state=0)

forest_importances = pd.Series(result.importances_mean, index=X.columns)

fig, ax = plt.subplots()

forest_importances.plot.bar(yerr=result.importances_std, ax=ax)

ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score

Yhat = rf.predict(X_test)

print("Acurácia dos dados de teste  : ", accuracy_score(Y_test,Yhat))
# Out:
# Acurácia dos dados de teste  :  0.0

# %%
rf.predict(X_test)
# Out:
# array(['Ghana', 'Bahamas, The', 'Latvia', 'Greenland',
#        'Falkland Islands (Malvinas)', 'St. Vincent and the Grenadines',
#        'Central African Rep.', 'Netherlands, The', 'West Bank and Gaza',
#        'Tajikistan, Rep. of', 'Honduras', 'Belgium', 'Indonesia',
#        'Montenegro', 'Botswana', 'Gabon', 'Guatemala', 'Netherlands, The',
#        'Latvia', 'Argentina', 'Dominica', 'Netherlands, The',
#        'South Sudan, Rep. of', 'Georgia', 'Nepal', 'Latvia', 'St. Lucia',
#        'Norway', 'India', 'Kenya', 'Anguilla',
#        'Wallis and Futuna Islands', 'Western Sahara',
#        'British Virgin Islands', 'Malawi', 'Czech Rep.', 'Algeria',
#        'Mauritania, Islamic Rep. of', 'Montenegro', 'Croatia, Rep. of',
#        'San Marino, Rep. of', 'Jamaica', 'San Marino, Rep. of', 'Austria',
#        'Cameroon', 'Isle of Man', 'Georgia', 'West Bank and Gaza',
#        'Lesotho, Kingdom of', 'British Virgin Islands', 'Vanuatu',
#        'St. Kitts and Nevis', 'Seychelles', 'Ghana', 'Thailand',
#        'Tanzania, United Rep. of', 'China, P.R.: Mainland'], dtype=object)

# %%
rf.predict_proba(X_test)
# Out:
# array([[0.   , 0.   , 0.   , ..., 0.02 , 0.   , 0.02 ],
#        [0.   , 0.   , 0.   , ..., 0.   , 0.02 , 0.   ],
#        [0.005, 0.   , 0.01 , ..., 0.005, 0.005, 0.   ],
#        ...,
#        [0.   , 0.005, 0.   , ..., 0.   , 0.   , 0.015],
#        [0.   , 0.01 , 0.   , ..., 0.005, 0.   , 0.03 ],
#        [0.   , 0.005, 0.   , ..., 0.02 , 0.   , 0.005]])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Displaying the confusion matrix

cm = confusion_matrix(Y_test, Yhat, labels=rf.classes_)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf.classes_)

disp.plot()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 6
#       2 import matplotlib.pyplot as plt
#       4 # Displaying the confusion matrix
# ----> 6 cm = confusion_matrix(Y_test, Yhat, labels=rf.classes_)
#       8 disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf.classes_)
#      10 disp.plot()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:333, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     331         return np.zeros((n_labels, n_labels), dtype=int)
#     332     elif len(np.intersect1d(y_true, labels)) == 0:
# --> 333         raise ValueError("At least one label specified must be in y_true")
#     335 if sample_weight is None:
#     336     sample_weight = np.ones(y_true.shape[0], dtype=np.int64)
#
# ValueError: At least one label specified must be in y_true
